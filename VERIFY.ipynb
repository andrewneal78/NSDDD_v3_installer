# %% [markdown]
# # NSDDD v3 Installation Notebook
#
# Welcome to the **National Security Documents Dataset** (NSDDD) version 3 installer.
#
# ## What is NSDDD v3?
#
# NSDDD v3 is a comprehensive corpus of **660 national security strategy documents** from **119 countries** spanning **1987–2025**, with **726,307 pre-computed semantic embeddings** (MPNet 768-dimensional vectors) enabling local semantic search without API keys.
#
# ## What You'll Get
#
# ✓ Semantic search across 660 national security documents
# ✓ 726K pre-computed MPNet embeddings (11GB)
# ✓ Complete metadata (countries, years, document types)
# ✓ Python code examples and tutorial notebook
# ✓ Full documentation and methodology
#
# ## Installation Overview
#
# - **Installation time**: 20–30 minutes
# - **Downloads**: 8–15 GB (depends on options selected)
# - **No API keys required** – all search runs locally
# - **Resume capability** – if interrupted, can continue from where it stopped
#
# ## Citation
#
# ```
# Neal, A. W., & Gardner, R. B. (2026). National Security and Defence Documents Dataset (1987-2025) v3.0.
# University of Edinburgh. https://datashare.ed.ac.uk
# ```
#
# ---
#
# **License**: Dataset is CC-BY 4.0 (Creative Commons Attribution 4.0 International)
#
# Let's get started! 👇

# %%
import sys
import platform
import shutil
import psutil
from pathlib import Path

print('='*70)
print('  System Requirements Check')
print('='*70 + '\n')

# Python version
python_version = sys.version_info
print(f'✓ Python version: {python_version.major}.{python_version.minor}.{python_version.micro}')
if python_version < (3, 9):
    print('\n✗ ERROR: Python 3.9 or newer required')
    print('Please upgrade Python and restart this notebook.')
    sys.exit(1)

# Operating system
system = platform.system()
print(f'✓ Operating system: {system}')

# Disk space
home_path = Path.home()
disk_stat = shutil.disk_usage(home_path)
free_gb = disk_stat.free / (1024**3)
print(f'✓ Free disk space: {free_gb:.1f} GB')
if free_gb < 15:
    print('\n⚠ WARNING: At least 15 GB free space recommended')
    print('You may not have enough space for the complete installation.')

# RAM
try:
    ram_gb = psutil.virtual_memory().total / (1024**3)
    print(f'✓ System RAM: {ram_gb:.1f} GB')
    if ram_gb < 16:
        print('\n⚠ WARNING: 16 GB RAM recommended')
        print('You may experience memory issues when loading the 11GB embedding file.')
except Exception:
    print('✓ System RAM: [Unable to check]')

print('\n' + '='*70)
print('✓ System requirements check complete')
print('='*70 + '\n')
# Out:
# ======================================================================
#   System Requirements Check
# ======================================================================
#
# ✓ Python version: 3.12.12
# ✓ Operating system: Darwin
# ✓ Free disk space: 254.3 GB
# ✓ System RAM: 36.0 GB
#
# ======================================================================
# ✓ System requirements check complete
# ======================================================================

# %%
# Initialize variables with defaults
# These will be used if you run all cells without clicking buttons

INSTALL_DIR = 'NSDDD_v3_workspace'
SELECTED_OPTIONAL = {
    'clean_text': False,
    'spacy': False,
    'pdf_originals': False,
    'original_language': False,
    'original_language_spacy': False
}

print('✓ Variables initialized')
print(f'  Install directory: {INSTALL_DIR}')
print(f'  Optional downloads: None (required files only)\n')
# Out:
# ✓ Variables initialized
#   Install directory: NSDDD_v3_workspace
#   Optional downloads: None (required files only)

# %%
import ipywidgets as widgets
from IPython.display import display, HTML

print('='*70)
print('  Installation Directory Setup')
print('='*70 + '\n')

print('Where would you like to install NSDDD v3?')
print('(The installer will create a directory with this name containing:')
print('  - model/ — Model files (11.5 GB)')
print('  - documents/ — Document files (optional, 0–13 GB)')
print('  - metadata/ — Metadata CSVs')
print('  - documentation/ — Documentation files)\n')

# Installation directory text input
install_dir_input = widgets.Text(
    value='NSDDD_v3_workspace',
    placeholder='Directory name',
    description='Install to:',
    style={'description_width': '120px'},
    layout=widgets.Layout(width='400px')
)

display(install_dir_input)

print('\nExample installation structure:')
print('NSDDD_v3_workspace/')
print('├── model/              ← 11.5 GB')
print('├── documents/          ← Optional documents')
print('├── metadata/')
print('├── documentation/')
print('└── downloads/          ← Temporary (can delete after installation)')

# Store for later use

def on_confirm_dir(b):
    global INSTALL_DIR
    INSTALL_DIR = install_dir_input.value
    print(f'\n✓ Installation directory set to: {INSTALL_DIR}')

confirm_button = widgets.Button(
    description='Continue',
    button_style='info',
    tooltip='Confirm installation directory'
)
confirm_button.on_click(on_confirm_dir)

display(confirm_button)
# Out:
# ======================================================================
#   Installation Directory Setup
# ======================================================================
#
# Where would you like to install NSDDD v3?
# (The installer will create a directory with this name containing:
#   - model/ — Model files (11.5 GB)
#   - documents/ — Document files (optional, 0–13 GB)
#   - metadata/ — Metadata CSVs
#   - documentation/ — Documentation files)
# Text(value='NSDDD_v3_workspace', description='Install to:', layout=Layout(width='400px'), placeholder='Directo…
# Example installation structure:
# NSDDD_v3_workspace/
# ├── model/              ← 11.5 GB
# ├── documents/          ← Optional documents
# ├── metadata/
# ├── documentation/
# └── downloads/          ← Temporary (can delete after installation)
# Button(button_style='info', description='Continue', style=ButtonStyle(), tooltip='Confirm installation directo…

# %%
print('\n' + '='*70)
print('  Download Selection')
print('='*70 + '\n')

print('NSDDD v3 is available as modular downloads. Select which components you need:\n')

# Required
print('🔵 REQUIRED (always selected):')
print('   ✓ Model files + metadata + docs — 4.7 GB')
print('     Contains: 726K semantic embeddings, segment data, metadata, guides\n')

# Optional
print('🟡 OPTIONAL (select as needed):')
print('   ☐ Clean text documents — 40 MB')
print('     Contains: 660 plain text files (English + translated)')
print('   ☐ SpaCy documents — 50 MB')
print('     Contains: 660 sentence-segmented files')
print('   ☐ PDF originals — 5 GB')
print('     Contains: 635 original PDFs organized by country (7.7GB uncompressed)')
print('   ☐ Original language documents — 10 MB')
print('     Contains: 128 original language plain text files')
print('   ☐ Original language SpaCy — 10 MB')
print('     Contains: 129 original language sentence-segmented files\n')

# Checkboxes for optional downloads
clean_text_cb = widgets.Checkbox(
    value=False,
    description='Clean text documents (40 MB)',
    layout=widgets.Layout(width='400px')
)
spacy_cb = widgets.Checkbox(
    value=False,
    description='SpaCy documents (50 MB)',
    layout=widgets.Layout(width='400px')
)
pdf_cb = widgets.Checkbox(
    value=False,
    description='PDF originals (5 GB) ⚠ Large!',
    layout=widgets.Layout(width='400px')
)
orig_lang_cb = widgets.Checkbox(
    value=False,
    description='Original language documents (10 MB)',
    layout=widgets.Layout(width='400px')
)
orig_lang_spacy_cb = widgets.Checkbox(
    value=False,
    description='SpaCy documents (50 MB)',
    layout=widgets.Layout(width='400px')
)

display(clean_text_cb, spacy_cb, pdf_cb, orig_lang_cb, orig_lang_spacy_cb)

# Output widget for dynamic updates
output = widgets.Output()
display(output)

# Calculate total size
def calculate_total():
    total_mb = 4700  # Required (model_files + metadata + docs)
    if clean_text_cb.value:
        total_mb += 40
    if spacy_cb.value:
        total_mb += 50
    if pdf_cb.value:
        total_mb += 5000
    if orig_lang_cb.value:
        total_mb += 10
    if orig_lang_spacy_cb.value:
        total_mb += 10
    
    total_gb = total_mb / 1024
    return total_mb, total_gb

# Update display when selections change
def update_totals(change):
    with output:
        output.clear_output(wait=True)
        total_mb, total_gb = calculate_total()
        free_gb_current = disk_stat.free / (1024**3)
        sufficient = free_gb_current >= total_gb
        status = '✓' if sufficient else '✗'
        print(f'\n{status} Total download size: {total_gb:.2f} GB')
        print(f'{status} Available disk space: {free_gb_current:.1f} GB\n')

# Observe checkboxes
clean_text_cb.observe(update_totals, names='value')
spacy_cb.observe(update_totals, names='value')
pdf_cb.observe(update_totals, names='value')
orig_lang_cb.observe(update_totals, names='value')
orig_lang_spacy_cb.observe(update_totals, names='value')

# Initial display
update_totals(None)

print('Selected components will be downloaded and verified.')
print('The installer supports resuming if interrupted.\n')

# Store selections

def on_confirm_downloads(b):
    global SELECTED_OPTIONAL
    SELECTED_OPTIONAL = {
        'clean_text': clean_text_cb.value,
        'spacy': spacy_cb.value,
        'pdf_originals': pdf_cb.value,
        'original_language': orig_lang_cb.value,
        'original_language_spacy': orig_lang_spacy_cb.value
    }
    total_mb, total_gb = calculate_total()
    with output:
        output.clear_output(wait=True)
        print(f'\n✓ Download selection confirmed')
        print(f'  Total: {total_gb:.2f} GB\n')

confirm_downloads_button = widgets.Button(
    description='Continue',
    button_style='info',
    tooltip='Confirm download selections'
)
confirm_downloads_button.on_click(on_confirm_downloads)

display(confirm_downloads_button)
# Out:
# ======================================================================
#   Download Selection
# ======================================================================
#
# NSDDD v3 is available as modular downloads. Select which components you need:
#
# 🔵 REQUIRED (always selected):
#    ✓ Model files + metadata + docs — 4.7 GB
#      Contains: 726K semantic embeddings, segment data, metadata, guides
#
# 🟡 OPTIONAL (select as needed):
#    ☐ Clean text documents — 40 MB
#      Contains: 660 plain text files (English + translated)
#    ☐ SpaCy documents — 50 MB
#      Contains: 660 sentence-segmented files
#    ☐ PDF originals — 5 GB
#      Contains: 635 original PDFs organized by country (7.7GB uncompressed)
#    ☐ Original language documents — 10 MB
#      Contains: 128 original language plain text files
#    ☐ Original language SpaCy — 10 MB
#      Contains: 129 original language sentence-segmented files
# Checkbox(value=False, description='Clean text documents (40 MB)', layout=Layout(width='400px'))
# Checkbox(value=False, description='SpaCy documents (50 MB)', layout=Layout(width='400px'))
# Checkbox(value=False, description='PDF originals (5 GB) ⚠ Large!', layout=Layout(width='400px'))
# Checkbox(value=False, description='Original language documents (10 MB)', layout=Layout(width='400px'))
# Checkbox(value=False, description='SpaCy documents (50 MB)', layout=Layout(width='400px'))
# Output()
# Selected components will be downloaded and verified.
# The installer supports resuming if interrupted.
# Button(button_style='info', description='Continue', style=ButtonStyle(), tooltip='Confirm download selections'…

# %%
print('\n' + '='*70)
print('  Installation Summary')
print('='*70 + '\n')

print(f'Installation directory: {INSTALL_DIR}')
print(f'\nDownloads:')
print(f'  ✓ Model files + metadata + docs: 8 GB (required)')

total_optional_gb = 0
if SELECTED_OPTIONAL['clean_text']:
    print(f'  ✓ Clean text documents: 0.04 GB')
    total_optional_gb += 0.04
if SELECTED_OPTIONAL['spacy']:
    print(f'  ✓ SpaCy documents: 0.05 GB')
    total_optional_gb += 0.05
if SELECTED_OPTIONAL['pdf_originals']:
    print(f'  ✓ PDF originals: 6 GB')
    total_optional_gb += 6
if SELECTED_OPTIONAL['original_language']:
    print(f'  ✓ Original language documents: 0.01 GB')
    total_optional_gb += 0.01
if SELECTED_OPTIONAL['original_language_spacy']:
    print(f'  ✓ Original language SpaCy: 0.01 GB')
    total_optional_gb += 0.01

total_gb = 8 + total_optional_gb
print(f'\nTotal download size: {total_gb:.2f} GB')
print(f'Available disk space: {disk_stat.free / (1024**3):.1f} GB')

if disk_stat.free / (1024**3) >= total_gb:
    print(f'✓ Sufficient disk space available')
else:
    print(f'✗ WARNING: Insufficient disk space!')

print(f'\nEstimated installation time:')
print(f'  • Fast connection (100 Mbps): 15–20 minutes')
print(f'  • Standard connection (25 Mbps): 30–45 minutes')
print(f'  • Slow connection (5 Mbps): 2–3 hours')

print(f'\nThe installation will:')
print(f'  1. Connect to Edinburgh DataShare')
print(f'  2. Download selected files')
print(f'  3. Extract and organize files')
print(f'  4. Verify checksums for integrity')
print(f'  5. Test model loading')
print(f'  6. Create working directory structure')

print(f'\nYou can resume if interrupted – downloads support resuming from where they stopped.\n')

ready_button = widgets.Button(
    description='Start Installation',
    button_style='success',
    tooltip='Begin NSDDD v3 installation'
)

def on_start_installation(b):
    print('Starting installation...\n')

ready_button.on_click(on_start_installation)
display(ready_button)
# Out:
# ======================================================================
#   Installation Summary
# ======================================================================
#
# Installation directory: NSDDD_v3_workspace
#
# Downloads:
#   ✓ Model files + metadata + docs: 8 GB (required)
#
# Total download size: 8.00 GB
# Available disk space: 254.3 GB
# ✓ Sufficient disk space available
#
# Estimated installation time:
#   • Fast connection (100 Mbps): 15–20 minutes
#   • Standard connection (25 Mbps): 30–45 minutes
#   • Slow connection (5 Mbps): 2–3 hours
#
# The installation will:
#   1. Connect to Edinburgh DataShare
#   2. Download selected files
#   3. Extract and organize files
#   4. Verify checksums for integrity
#   5. Test model loading
#   6. Create working directory structure
#
# You can resume if interrupted – downloads support resuming from where they stopped.
# Button(button_style='success', description='Start Installation', style=ButtonStyle(), tooltip='Begin NSDDD v3 …

# %%
print('='*70)
print('  Environment Setup')
print('='*70 + '\n')

print('Importing required modules...\n')

import os
import json
import time
import zipfile
import subprocess
from pathlib import Path
from tqdm.notebook import tqdm
import requests
import numpy as np

print('✓ Core imports successful\n')

# Import local utilities
import sys
sys.path.insert(0, str(Path.cwd()))

try:
    from config import DATASHARE_HANDLE, DATASHARE_API_BASE, DOWNLOADS
    from utils.datashare import DataShareClient
    from utils.download import download_file, calculate_total_size, check_disk_space
    from utils.verify import verify_file, load_checksums_file, verify_directory
    from utils.setup import create_directory_structure, display_directory_structure, get_directory_size
    print('✓ Local utilities imported successfully\n')
except ImportError as e:
    print(f'✗ Error importing local modules: {e}')
    print('Make sure you are running this notebook from the installer directory.')
    raise
# Out:
# ======================================================================
#   Environment Setup
# ======================================================================
#
# Importing required modules...
# ✓ Core imports successful
#
# ✓ Local utilities imported successfully

# %%
print('Checking virtual environment...\n')

in_venv = hasattr(sys, 'real_prefix') or (hasattr(sys, 'base_prefix') and sys.base_prefix != sys.prefix)

if in_venv:
    print('✓ Already in a virtual environment')
    print(f'  Location: {sys.prefix}')
else:
    print('⚠ Not in a virtual environment')
    print('\nVirtual environments are recommended for:')
    print('  • Version isolation')
    print('  • Easy cleanup')
    print('  • Avoiding conflicts with other projects')
    print('\nYou can continue without a venv, or create one manually:')
    print('  python3 -m venv NSDDD_v3_env')
    print('  source NSDDD_v3_env/bin/activate  # macOS/Linux')
    print('  .\\NSDDD_v3_env\\Scripts\\activate  # Windows')

print('\n✓ Environment check complete\n')
# Out:
# Checking virtual environment...
#
# ✓ Already in a virtual environment
#   Location: /Users/aneal/.venv
#
# ✓ Environment check complete

# %%
print('Installing Python dependencies...\n')
print('This may take 2–5 minutes...\n')

# Read requirements
requirements_file = Path('requirements.txt')
if not requirements_file.exists():
    print('✗ Error: requirements.txt not found')
    print('Make sure you are in the installer directory.')
    sys.exit(1)

# Install using pip
result = subprocess.run(
    [sys.executable, '-m', 'pip', 'install', '-q', '-r', str(requirements_file)],
    capture_output=True,
    text=True
)

if result.returncode == 0:
    print('✓ Dependencies installed successfully\n')
else:
    print('✗ Error installing dependencies:')
    print(result.stderr)
    raise RuntimeError('Dependency installation failed')

# Verify critical imports
try:
    import sentence_transformers
    import torch
    import numpy
    import scipy
    import tqdm
    import requests
    print('✓ All critical packages verified\n')
except ImportError as e:
    print(f'✗ Error: Missing package: {e}')
    raise
# Out:
# Installing Python dependencies...
#
# This may take 2–5 minutes...
# ✓ Dependencies installed successfully
# ✓ All critical packages verified

# %%
print('Verifying sentence-transformers model...\n')
print('(This downloads the MPNet model if not already cached)\n')

try:
    from sentence_transformers import SentenceTransformer

    print('Loading sentence-transformers/all-mpnet-base-v2...')
    print('(First time may take 1–2 minutes and ~500 MB)\n')

    model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

    # Test encoding
    test_sentences = ['Cyber threats to critical infrastructure']
    embeddings = model.encode(test_sentences)

    print(f'✓ Model loaded successfully')
    print(f'  Model: sentence-transformers/all-mpnet-base-v2')
    print(f'  Embedding dimension: {embeddings.shape[1]}')
    print(f'  Cache location: {model.get_sentence_embedding_dimension()}')
    print(f'\n✓ Environment setup complete\n')

except Exception as e:
    print(f'✗ Error loading model: {e}')
    raise
# Out:
# Verifying sentence-transformers model...
#
# (This downloads the MPNet model if not already cached)
#
# Loading sentence-transformers/all-mpnet-base-v2...
# (First time may take 1–2 minutes and ~500 MB)
# ✓ Model loaded successfully
#   Model: sentence-transformers/all-mpnet-base-v2
#   Embedding dimension: 768
#   Cache location: 768
#
# ✓ Environment setup complete

# %%
print('='*70)
print('  Connecting to Edinburgh DataShare')
print('='*70 + '\n')

print(f'DataShare handle: {DATASHARE_HANDLE}')
print(f'API base: {DATASHARE_API_BASE}\n')

try:
    client = DataShareClient(DATASHARE_API_BASE, DATASHARE_HANDLE)

    print('Fetching dataset information...\n')

    summary = client.get_dataset_summary()

    print(f'✓ Connected successfully')
    print(f'  Files in dataset: {summary["file_count"]}')
    print(f'  Total size: {summary["total_size_gb"]:.2f} GB\n')

    print('Available files:')
    for filename in sorted(summary['files']):
        file_info = client.get_file_info(filename)
        print(f'  • {filename}: {file_info["size_gb"]:.2f} GB')

    print(f'\n✓ DataShare connection established\n')

except Exception as e:
    print(f'✗ Error connecting to DataShare: {e}')
    print(f'\nTroubleshooting:')
    print(f'  • Check internet connection')
    print(f'  • Verify DataShare is accessible: https://datashare.ed.ac.uk')
    print(f'  • Check if handle is correct in config.py')
    raise
# Out:
# ======================================================================
#   Connecting to Edinburgh DataShare
# ======================================================================
#
# DataShare handle: 10283/[HANDLE_TO_BE_ADDED]
# API base: https://datashare.ed.ac.uk/rest
#
# Fetching dataset information...
# ✗ Error connecting to DataShare: 500 Server Error: 500 for url: https://datashare.ed.ac.uk/rest/handle/10283/%5BHANDLE_TO_BE_ADDED%5D
#
# Troubleshooting:
#   • Check internet connection
#   • Verify DataShare is accessible: https://datashare.ed.ac.uk
#   • Check if handle is correct in config.py
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[10], line 13
#       9 client = DataShareClient(DATASHARE_API_BASE, DATASHARE_HANDLE)
#      11 print('Fetching dataset information...\n')
# ---> 13 summary = client.get_dataset_summary()
#      15 print(f'✓ Connected successfully')
#      16 print(f'  Files in dataset: {summary["file_count"]}')
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:195, in DataShareClient.get_dataset_summary(self)
#     188 def get_dataset_summary(self) -> Dict:
#     189     """
#     190     Get summary information about the dataset.
#     191
#     192     Returns:
#     193         Dictionary with dataset info (files, total size, etc.)
#     194     """
# --> 195     bitstreams = self.list_bitstreams()
#     197     total_size_bytes = sum(b.get('size', 0) for b in bitstreams)
#     198     total_size_gb = total_size_bytes / (1024 ** 3)
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:89, in DataShareClient.list_bitstreams(self)
#      74 def list_bitstreams(self) -> List[Dict]:
#      75     """
#      76     List all files (bitstreams) in the dataset.
#      77
#    (...)     87         requests.RequestException: If API request fails
#      88     """
# ---> 89     item_id = self._get_item_id()
#      90     url = f'{self.api_base}/items/{item_id}/bitstreams'
#      91     response = self.session.get(url, timeout=10)
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:70, in DataShareClient._get_item_id(self)
#      63 """
#      64 Get item ID from handle (with caching).
#      65
#      66 Returns:
#      67     Item ID as integer
#      68 """
#      69 if self._item_id is None:
# ---> 70     metadata = self.get_item_metadata()
#      71     self._item_id = metadata['id']
#      72 return self._item_id
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:53, in DataShareClient.get_item_metadata(self)
#      51 url = f'{self.api_base}/handle/{self.handle}'
#      52 response = self.session.get(url, timeout=10)
# ---> 53 response.raise_for_status()
#      55 data = response.json()
#      56 if not data or 'id' not in data:
#
# File ~/.venv/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: 500 for url: https://datashare.ed.ac.uk/rest/handle/10283/%5BHANDLE_TO_BE_ADDED%5D

# %%
print('Creating installation directory structure...\n')

base_path = Path(INSTALL_DIR)

try:
    directories = create_directory_structure(str(base_path))

    print(f'✓ Directory structure created:')
    for name, path in directories.items():
        if name != 'base':
            print(f'  ✓ {name}/: {path}')

    print(f'\n✓ Installation directory ready: {base_path}\n')

except Exception as e:
    print(f'✗ Error creating directories: {e}')
    raise
# Out:
# Creating installation directory structure...
#
# ✓ Directory structure created:
#   ✓ model/: NSDDD_v3_workspace/model
#   ✓ documents/: NSDDD_v3_workspace/documents
#   ✓ metadata/: NSDDD_v3_workspace/metadata
#   ✓ documentation/: NSDDD_v3_workspace/documentation
#   ✓ downloads/: NSDDD_v3_workspace/downloads
#
# ✓ Installation directory ready: NSDDD_v3_workspace

# %%
print('='*70)
print('  Downloading Required Files')
print('='*70 + '\n')

downloads_dir = base_path / 'downloads'
required_files = ['model_files', 'metadata', 'documentation']

for file_key in required_files:
    download_spec = DOWNLOADS[file_key]
    filename = download_spec['filename']

    print(f'Downloading {filename}...')
    print(f'Size: {download_spec["size_gb"]:.2f} GB\n')

    try:
        file_info = client.get_file_info(filename)
        download_url = file_info['download_url']

        destination = downloads_dir / filename

        # Progress callback
        def progress_callback(downloaded, total):
            percent = (downloaded / total) * 100 if total > 0 else 0
            mb_downloaded = downloaded / (1024 ** 2)
            mb_total = total / (1024 ** 2)
            print(f'  {percent:.1f}% ({mb_downloaded:.0f} MB / {mb_total:.0f} MB)', end='\r')

        # Download with resume
        downloaded_file = download_file(
            url=download_url,
            destination=str(destination),
            resume=True,
            progress_callback=progress_callback
        )

        print(f'  ✓ Download complete: {filename}                    \n')

    except Exception as e:
        print(f'  ✗ Error downloading {filename}: {e}')
        print(f'  Note: You can restart this cell to resume downloading.\n')
        raise

print(f'✓ All required files downloaded\n')
# Out:
# ======================================================================
#   Downloading Required Files
# ======================================================================
#
# Downloading model_files.zip...
# Size: 4.70 GB
#   ✗ Error downloading model_files.zip: 500 Server Error: 500 for url: https://datashare.ed.ac.uk/rest/handle/10283/%5BHANDLE_TO_BE_ADDED%5D
#   Note: You can restart this cell to resume downloading.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[12], line 16
#      13 print(f'Size: {download_spec["size_gb"]:.2f} GB\n')
#      15 try:
# ---> 16     file_info = client.get_file_info(filename)
#      17     download_url = file_info['download_url']
#      19     destination = downloads_dir / filename
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:148, in DataShareClient.get_file_info(self, filename)
#     131 def get_file_info(self, filename: str) -> Dict:
#     132     """
#     133     Get detailed information about a file.
#     134
#    (...)    146         - checksum: SHA-256 checksum if available
#     147     """
# --> 148     bitstream = self.find_file_by_name(filename)
#     150     size_bytes = bitstream.get('size', 0)
#     151     size_mb = size_bytes / (1024 ** 2)
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:120, in DataShareClient.find_file_by_name(self, filename)
#     107 def find_file_by_name(self, filename: str) -> Dict:
#     108     """
#     109     Find a specific file by name in the dataset.
#     110
#    (...)    118         FileNotFoundError: If file not found in dataset
#     119     """
# --> 120     bitstreams = self.list_bitstreams()
#     121     for bitstream in bitstreams:
#     122         if bitstream.get('name') == filename:
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:89, in DataShareClient.list_bitstreams(self)
#      74 def list_bitstreams(self) -> List[Dict]:
#      75     """
#      76     List all files (bitstreams) in the dataset.
#      77
#    (...)     87         requests.RequestException: If API request fails
#      88     """
# ---> 89     item_id = self._get_item_id()
#      90     url = f'{self.api_base}/items/{item_id}/bitstreams'
#      91     response = self.session.get(url, timeout=10)
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:70, in DataShareClient._get_item_id(self)
#      63 """
#      64 Get item ID from handle (with caching).
#      65
#      66 Returns:
#      67     Item ID as integer
#      68 """
#      69 if self._item_id is None:
# ---> 70     metadata = self.get_item_metadata()
#      71     self._item_id = metadata['id']
#      72 return self._item_id
#
# File ~/Library/CloudStorage/OneDrive-UniversityofEdinburgh/national_security_analysis/NSDDD_v3/NSDDD_v3_installer/utils/datashare.py:53, in DataShareClient.get_item_metadata(self)
#      51 url = f'{self.api_base}/handle/{self.handle}'
#      52 response = self.session.get(url, timeout=10)
# ---> 53 response.raise_for_status()
#      55 data = response.json()
#      56 if not data or 'id' not in data:
#
# File ~/.venv/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 500 Server Error: 500 for url: https://datashare.ed.ac.uk/rest/handle/10283/%5BHANDLE_TO_BE_ADDED%5D

# %%
print('='*70)
print('  Extracting and Verifying Files')
print('='*70 + '\n')

for file_key in required_files:
    download_spec = DOWNLOADS[file_key]
    filename = download_spec['filename']
    extract_to = base_path / download_spec['extract_to']

    zip_path = downloads_dir / filename

    print(f'Extracting {filename}...')

    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(str(extract_to))

        print(f'  ✓ Extraction complete\n')

    except Exception as e:
        print(f'  ✗ Error extracting {filename}: {e}')
        raise

print(f'✓ All files extracted\n')

# Verify model files with checksums
print('Verifying model file integrity...\n')

checksum_file = base_path / 'model' / 'checksums.txt'
if checksum_file.exists():
    try:
        checksums = load_checksums_file(checksum_file)
        all_valid, results = verify_directory(
            base_path / 'model',
            checksums,
            verbose=True
        )

        if all_valid:
            print(f'\n✓ All files verified successfully\n')
        else:
            print(f'\n✗ Verification failed!')
            print(f'  Mismatches: {len(results["mismatches"])}')
            print(f'  Missing: {len(results["missing"])}')
            raise RuntimeError('File verification failed')

    except Exception as e:
        print(f'  ✗ Error during verification: {e}')
        raise
else:
    print('⚠ checksums.txt not found – skipping verification')
# Out:
# ======================================================================
#   Extracting and Verifying Files
# ======================================================================
#
# Extracting model_files.zip...
#   ✗ Error extracting model_files.zip: [Errno 2] No such file or directory: 'NSDDD_v3_workspace/downloads/model_files.zip'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 15
#      12 print(f'Extracting {filename}...')
#      14 try:
# ---> 15     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#      16         zip_ref.extractall(str(extract_to))
#      18     print(f'  ✓ Extraction complete\n')
#
# File /opt/homebrew/Cellar/python@3.12/3.12.12/Frameworks/Python.framework/Versions/3.12/lib/python3.12/zipfile/__init__.py:1352, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1350 while True:
#    1351     try:
# -> 1352         self.fp = io.open(file, filemode)
#    1353     except OSError:
#    1354         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NSDDD_v3_workspace/downloads/model_files.zip'

# %%
print('='*70)
print('  Downloading Optional Files')
print('='*70 + '\n')

optional_keys = [
    ('clean_text', 'clean_text_documents_English_and_translated.zip'),
    ('spacy', 'spacy_documents.zip'),
    ('pdf_originals', 'pdf_originals.zip'),
    ('original_language', 'original_language_documents.zip'),
    ('original_language_spacy', 'original_language_spacy.zip')
]

for key, filename in optional_keys:
    if not SELECTED_OPTIONAL[key]:
        print(f'⊘ Skipping {filename} (not selected)\n')
        continue

    download_spec = DOWNLOADS[key]

    print(f'Downloading {filename}...')
    print(f'Size: {download_spec["size_gb"]:.2f} GB\n')

    try:
        file_info = client.get_file_info(filename)
        download_url = file_info['download_url']

        destination = downloads_dir / filename

        def progress_callback(downloaded, total):
            percent = (downloaded / total) * 100 if total > 0 else 0
            mb_downloaded = downloaded / (1024 ** 2)
            mb_total = total / (1024 ** 2)
            print(f'  {percent:.1f}% ({mb_downloaded:.0f} MB / {mb_total:.0f} MB)', end='\r')

        downloaded_file = download_file(
            url=download_url,
            destination=str(destination),
            resume=True,
            progress_callback=progress_callback
        )

        print(f'  ✓ Download complete: {filename}                    \n')

    except Exception as e:
        print(f'  ✗ Error downloading {filename}: {e}')
        print(f'  Note: You can restart this cell to resume.\n')

print(f'✓ Optional file downloads complete\n')
# Out:
# ======================================================================
#   Downloading Optional Files
# ======================================================================
#
# ⊘ Skipping clean_text_documents_English_and_translated.zip (not selected)
#
# ⊘ Skipping spacy_documents.zip (not selected)
#
# ⊘ Skipping pdf_originals.zip (not selected)
#
# ⊘ Skipping original_language_documents.zip (not selected)
#
# ⊘ Skipping original_language_spacy.zip (not selected)
#
# ✓ Optional file downloads complete

# %%
print('Extracting optional files...\n')

for key, filename in optional_keys:
    if not SELECTED_OPTIONAL[key]:
        continue

    zip_path = downloads_dir / filename

    if not zip_path.exists():
        print(f'⊘ Skipping {filename} (not downloaded)')
        continue

    extract_to = base_path / 'documents'

    print(f'Extracting {filename}...')

    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(str(extract_to))

        print(f'  ✓ Extraction complete\n')

    except Exception as e:
        print(f'  ✗ Error extracting {filename}: {e}')
        raise

print(f'✓ Optional files extracted\n')
# Out:
# Extracting optional files...
#
# ✓ Optional files extracted

# %%
print('='*70)
print('  Installation Directory Structure')
print('='*70 + '\n')

display_directory_structure(str(base_path), 'Final Installation Structure')

# Calculate directory sizes
print('\nDirectory sizes:')
for subdir in ['model', 'documents', 'metadata', 'documentation']:
    subdir_path = base_path / subdir
    if subdir_path.exists():
        size_info = get_directory_size(str(subdir_path))
        print(f'  {subdir}/: {size_info["size_gb"]:.2f} GB ({size_info["file_count"]} files)')

total_size = get_directory_size(str(base_path))
print(f'\n  Total: {total_size["size_gb"]:.2f} GB ({total_size["file_count"]} files)')

print(f'\n✓ Installation directory structure complete\n')
# Out:
# ======================================================================
#   Installation Directory Structure
# ======================================================================
#
#
# Final Installation Structure
# ============================================================
# NSDDD_v3_workspace/
# ├── documentation/
# ├── documents/
# ├── downloads/
# ├── metadata/
# └── model/
#
#
# Directory sizes:
#   model/: 0.00 GB (0 files)
#   documents/: 0.00 GB (0 files)
#   metadata/: 0.00 GB (0 files)
#   documentation/: 0.00 GB (0 files)
#
#   Total: 0.00 GB (0 files)
#
# ✓ Installation directory structure complete

# %%
print('='*70)
print('  Verification Tests')
print('='*70 + '\n')

print('Loading model files...\n')
print('(This takes 90–120 seconds for the 11GB embedding file)\n')

model_dir = base_path / 'model'

try:
    # Load segment encodings (largest file)
    print('Loading segment_encodings.json (11GB)...')
    start = time.time()

    with open(model_dir / 'segment_encodings.json', 'r') as f:
        segment_encodings = json.load(f)
        segment_encodings = np.array(segment_encodings)

    elapsed = time.time() - start
    print(f'  ✓ Loaded: {segment_encodings.shape[0]:,} embeddings ({segment_encodings.shape[1]} dimensions) in {elapsed:.1f}s')

    # Load segments
    print('\nLoading segments_dict.json...')
    with open(model_dir / 'segments_dict.json', 'r') as f:
        segments_dict = json.load(f)
    print(f'  ✓ Loaded: {len(segments_dict):,} segments')

    # Load encoded segments list
    print('Loading encoded_segments.json...')
    with open(model_dir / 'encoded_segments.json', 'r') as f:
        encoded_segments = json.load(f)
    print(f'  ✓ Loaded: {len(encoded_segments):,} segment IDs')

    # Load documents
    print('Loading documents_dict.json...')
    with open(model_dir / 'documents_dict.json', 'r') as f:
        documents_dict = json.load(f)
    print(f'  ✓ Loaded: {len(documents_dict):,} documents')

    # Load countries
    print('Loading countries_dict.json...')
    with open(model_dir / 'countries_dict.json', 'r') as f:
        countries_dict = json.load(f)
    print(f'  ✓ Loaded: {len(countries_dict):,} countries')

    print(f'\n✓ All model files loaded successfully\n')

except Exception as e:
    print(f'✗ Error loading model files: {e}')
    raise
# Out:
# ======================================================================
#   Verification Tests
# ======================================================================
#
# Loading model files...
#
# (This takes 90–120 seconds for the 11GB embedding file)
#
# Loading segment_encodings.json (11GB)...
# ✗ Error loading model files: [Errno 2] No such file or directory: 'NSDDD_v3_workspace/model/segment_encodings.json'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 15
#      12 print('Loading segment_encodings.json (11GB)...')
#      13 start = time.time()
# ---> 15 with open(model_dir / 'segment_encodings.json', 'r') as f:
#      16     segment_encodings = json.load(f)
#      17     segment_encodings = np.array(segment_encodings)
#
# File ~/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'NSDDD_v3_workspace/model/segment_encodings.json'

# %%
print('Testing semantic search...\n')

# Test query
test_query = 'Cyber threats to critical infrastructure'

print(f'Test query: "{test_query}"\n')

try:
    # Encode query
    print('Encoding query...')
    query_embedding = model.encode([test_query])[0]
    print(f'  ✓ Query encoded to {len(query_embedding)} dimensions\n')

    # Compute similarities
    print('Computing similarities against all segments...')
    similarities = []
    for encoding in segment_encodings:
        from scipy.spatial.distance import cosine
        sim = 1 - cosine(query_embedding, encoding)
        similarities.append(sim)

    similarities = np.array(similarities)
    print(f'  ✓ Computed {len(similarities):,} similarity scores\n')

    # Get top results
    top_indices = np.argsort(similarities)[::-1][:10]

    print('Top 10 results:')
    print(f'{"Rank":<5} {"Segment":<15} {"Similarity":<12} {"Preview"}')
    print('─' * 70)

    for rank, idx in enumerate(top_indices, 1):
        segment_id = encoded_segments[idx]
        similarity = similarities[idx]

        # Get segment text
        if segment_id in segments_dict:
            text = segments_dict[segment_id][:50] + '...'
        else:
            text = '[Text not found]'

        print(f'{rank:<5} {segment_id:<15} {similarity:<12.3f} {text}')

    print(f'\n✓ Semantic search test successful\n')

except Exception as e:
    print(f'✗ Error during semantic search test: {e}')
    raise
# Out:
# Testing semantic search...
#
# Test query: "Cyber threats to critical infrastructure"
#
# Encoding query...
#   ✓ Query encoded to 768 dimensions
#
# Computing similarities against all segments...
# ✗ Error during semantic search test: name 'segment_encodings' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 17
#      15 print('Computing similarities against all segments...')
#      16 similarities = []
# ---> 17 for encoding in segment_encodings:
#      18     from scipy.spatial.distance import cosine
#      19     sim = 1 - cosine(query_embedding, encoding)
#
# NameError: name 'segment_encodings' is not defined

# %%
print('='*70)
print('  ✓✓✓ All Verification Tests Passed')
print('='*70 + '\n')

print('Installation Status:')
print(f'  ✓ System requirements verified')
print(f'  ✓ Dependencies installed')
print(f'  ✓ Model files downloaded and verified')
print(f'  ✓ Directory structure created')
print(f'  ✓ Model files loaded successfully')
print(f'  ✓ Semantic search functional')

print(f'\nInstallation Details:')
print(f'  Location: {base_path}')
print(f'  Total size: {total_size["size_gb"]:.2f} GB')
print(f'  Documents: {len(documents_dict):,}')
print(f'  Countries: {len(countries_dict):,}')
print(f'  Segments: {len(segments_dict):,}')
print(f'  Embeddings: {segment_encodings.shape[0]:,}')

print(f'\nYou are ready to use NSDDD v3!\n')
# Out:
# ======================================================================
#   ✓✓✓ All Verification Tests Passed
# ======================================================================
#
# Installation Status:
#   ✓ System requirements verified
#   ✓ Dependencies installed
#   ✓ Model files downloaded and verified
#   ✓ Directory structure created
#   ✓ Model files loaded successfully
#   ✓ Semantic search functional
#
# Installation Details:
#   Location: NSDDD_v3_workspace
#   Total size: 0.00 GB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 16
#      14 print(f'  Location: {base_path}')
#      15 print(f'  Total size: {total_size["size_gb"]:.2f} GB')
# ---> 16 print(f'  Documents: {len(documents_dict):,}')
#      17 print(f'  Countries: {len(countries_dict):,}')
#      18 print(f'  Segments: {len(segments_dict):,}')
#
# NameError: name 'documents_dict' is not defined

# %%
print('='*70)
print('  Cleanup Options')
print('='*70 + '\n')

print('Temporary download files:')
for zip_file in downloads_dir.glob('*.zip'):
    size_gb = zip_file.stat().st_size / (1024**3)
    print(f'  • {zip_file.name}: {size_gb:.2f} GB')

print(f'\nThese zip files are no longer needed after extraction.')
print(f'Deleting them would free up disk space for other use.')

cleanup_cb = widgets.Checkbox(
    value=False,
    description='Delete downloaded zip files (frees ~8–15 GB)'
)
display(cleanup_cb)

def on_cleanup(b):
    if cleanup_cb.value:
        print('\nDeleting temporary zip files...')
        freed_mb = 0
        for zip_file in downloads_dir.glob('*.zip'):
            size = zip_file.stat().st_size
            zip_file.unlink()
            freed_mb += size / (1024**2)
            print(f'  ✓ Deleted {zip_file.name}')

        freed_gb = freed_mb / 1024
        print(f'\n✓ Freed {freed_gb:.1f} GB of disk space')
    else:
        print('\n✓ Keeping zip files')

cleanup_button = widgets.Button(
    description='Confirm',
    button_style='warning'
)
cleanup_button.on_click(on_cleanup)
display(cleanup_button)
# Out:
# ======================================================================
#   Cleanup Options
# ======================================================================
#
# Temporary download files:
#
# These zip files are no longer needed after extraction.
# Deleting them would free up disk space for other use.
# Checkbox(value=False, description='Delete downloaded zip files (frees ~8–15 GB)')
# Button(button_style='warning', description='Confirm', style=ButtonStyle())

# %% [markdown]
# ## Next Steps### 1. Open the Document Search InterfaceOpen the **Document Metadata Search Tool**:```bashjupyter notebook document_metadata_search.ipynb```This provides an **interactive widget interface** for searching:- **No Python coding required** – use dropdown menus and text boxes- **Semantic search** – finds conceptually similar content- **Advanced filtering** – by country, region, organization, income, democracy status, year- **Results with context** – similarity scores, document metadata, clustering- **Export to CSV** – save results for further analysis**Quick start:**1. Run all cells in the notebook to load the dataset2. Enter search queries in the text box (e.g., 'cyber threats to critical infrastructure')3. Select filters using dropdown menus4. Click 'Search' to find matching segments5. Review results and export if needed### 2. Read the DocumentationDocumentation files are in `[installation-directory]/documentation/`:- **WHATS_NEW_IN_NSDDD_V3.md** – Complete guide to semantic search methodology- **WHATS_NEW_IN_NSDDD_V3.md** – Dataset composition and improvements- **dataset_inclusion_criteria.md** – Document selection criteria- **WHATS_NEW_IN_NSDDD_V3.md** – Language coverage analysis### 3. Example Search QueriesTry these queries in the search interface:- `cyber threats to critical infrastructure`- `climate change as a national security threat`- `terrorism and non-state actors`- `supply chain security and dependencies`- `economic coercion and economic warfare`- `migration and border security`- `disinformation and hybrid warfare`Combine with filters to target specific:- **Countries** (single or multiple selection)- **Regions** (Asia, Europe, Africa, Americas, Oceania)- **Organizations** (NATO, EU, ASEAN, BRICS, Commonwealth, etc.)- **Years** (1987–2025)### 4. CitationWhen publishing research using NSDDD v3, cite:```Neal, A. W., & Gardner, R. B. (2026). National Security and Defence Documents Dataset (1987-2025) v3.0.University of Edinburgh. https://datashare.ed.ac.uk```### 5. Support- **Issues or questions?** Check the documentation files in `documentation/`- **Bug reports?** Open an issue on GitHub- **Questions about the dataset?** See WHATS_NEW_IN_NSDDD_V3.md---**Happy researching!** 🔍All 660 national security documents are now ready for semantic search on your computer.

# %%
print('\n' + '='*70)
print('  ✓✓✓ INSTALLATION COMPLETE ✓✓✓')
print('='*70)

print(f'''
National Security Documents Dataset (NSDDD) v3
Successfully installed!

Installation Details:
  • Semantic search: Ready ✓
  • 660 documents from 119 countries (1987–2025)
  • 726,307 pre-computed embeddings (768-dimensional)
  • All searches run locally – no internet connection needed after this

Quick Start:
  1. Open GETTING_STARTED.ipynb for tutorial
  2. Read documentation/ for methodology and guides
  3. Try example semantic searches
  4. Cite NSDDD v3 in your research

Support:
  • Documentation: See documentation/ directory
  • Issues: GitHub issues
  • Questions: See included documentation

Citation:
  Neal, A. W., & Gardner, R. B. (2026). National Security and Defence Documents Dataset (1987-2025) v3.0.
  University of Edinburgh. https://datashare.ed.ac.uk

Thank you for using NSDDD v3! 🔍
''')

print('='*70 + '\n')
# Out:
# ======================================================================
#   ✓✓✓ INSTALLATION COMPLETE ✓✓✓
# ======================================================================
#
# National Security Documents Dataset (NSDDD) v3
# Successfully installed!
#
# Installation Details:
#   • Semantic search: Ready ✓
#   • 660 documents from 119 countries (1987–2025)
#   • 726,307 pre-computed embeddings (768-dimensional)
#   • All searches run locally – no internet connection needed after this
#
# Quick Start:
#   1. Open GETTING_STARTED.ipynb for tutorial
#   2. Read documentation/ for methodology and guides
#   3. Try example semantic searches
#   4. Cite NSDDD v3 in your research
#
# Support:
#   • Documentation: See documentation/ directory
#   • Issues: GitHub issues
#   • Questions: See included documentation
#
# Citation:
#   Gardner, A. N. (2025). National Security Documents Dataset (NSDDD) Version 3.
#   University of Edinburgh. https://doi.org/10.7488/ds/[DOI_TO_BE_ADDED]
#
# Thank you for using NSDDD v3! 🔍
#
# ======================================================================
